# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/DL Project - yaniv'
# !pip install -r 'Wave-U-Net-Pytorch-master-fine tuning/requirements.txt'

# %%
# !python 'Wave-U-Net-Pytorch-master-fine tuning/train.py' --load_model "checkpoints/waveunet/model" --dataset_dir 'MUSDB18_format_of_SNSD' --cuda
# Out:
# Streaming output truncated to the last 5000 lines.
#  91% 597/657 [05:47<00:34,  1.72it/s]['bass', 'drums', 'other', 'vocals']
#  91% 598/657 [05:47<00:34,  1.73it/s]['bass', 'drums', 'other', 'vocals']
#  91% 599/657 [05:48<00:33,  1.73it/s]['bass', 'drums', 'other', 'vocals']
#  91% 600/657 [05:48<00:32,  1.73it/s]['bass', 'drums', 'other', 'vocals']
#  91% 601/657 [05:49<00:35,  1.58it/s]['bass', 'drums', 'other', 'vocals']
#  92% 602/657 [05:50<00:34,  1.61it/s]['bass', 'drums', 'other', 'vocals']
#  92% 603/657 [05:50<00:32,  1.64it/s]['bass', 'drums', 'other', 'vocals']
#  92% 604/657 [05:51<00:31,  1.67it/s]['bass', 'drums', 'other', 'vocals']
#  92% 605/657 [05:51<00:30,  1.69it/s]['bass', 'drums', 'other', 'vocals']
#  92% 606/657 [05:52<00:29,  1.71it/s]['bass', 'drums', 'other', 'vocals']
#  92% 607/657 [05:53<00:29,  1.71it/s]['bass', 'drums', 'other', 'vocals']
#  93% 608/657 [05:53<00:28,  1.72it/s]['bass', 'drums', 'other', 'vocals']
# ...

# %%
# !python 'Wave-U-Net-Pytorch-master-fine tuning/train.py' --load_model "Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_20398" --dataset_dir 'MUSDB18_format_of_SNSD' --cuda
# Out:
# Streaming output truncated to the last 5000 lines.
# 100% 656/657 [06:18<00:00,  1.74it/s]['bass', 'drums', 'other', 'vocals']
# 100% 657/657 [06:18<00:00,  1.74it/s]['bass', 'drums', 'other', 'vocals']
# 658it [06:18,  1.74it/s]
#   0% 0/234 [00:00<?, ?it/s]['bass', 'drums', 'other', 'vocals']
# Current loss: 0.0135:   0% 1/234 [00:00<02:07,  1.82it/s]['bass', 'drums', 'other', 'vocals']
# Current loss: 0.0126:   1% 2/234 [00:00<01:16,  3.02it/s]['bass', 'drums', 'other', 'vocals']
# Current loss: 0.0127:   1% 3/234 [00:00<01:00,  3.81it/s]['bass', 'drums', 'other', 'vocals']
# Current loss: 0.0127:   2% 4/234 [00:01<00:52,  4.37it/s]['bass', 'drums', 'other', 'vocals']
# Current loss: 0.0136:   2% 5/234 [00:01<00:48,  4.73it/s]['bass', 'drums', 'other', 'vocals']
# Current loss: 0.0141:   3% 6/234 [00:01<00:45,  4.99it/s]['bass', 'drums', 'other', 'vocals']
# Current loss: 0.0144:   3% 7/234 [00:01<00:44,  5.12it/s]['bass', 'drums', 'other', 'vocals']
# ...

# %%
# !python "Wave-U-Net-Pytorch-master-fine tuning/predict.py" --load_model "Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_20398" --input "/content/drive/MyDrive/DL Project - yaniv/audio examples/noisy speech 3 - moshe/noisy7_SNRdb_20.0_clnsp7.wav" --cuda
# Out:
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# Loading model from checkpoint Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_20398
# Step 20398
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples

# %%
# !python "Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py" --load_model "Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_20398" --folder "/content/drive/MyDrive/DL Project - yaniv/MUSDB18_format_of_SNSD/test" --cuda
# Out:
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# 26.55515193939209
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# 27.862930297851562
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# 26.447110176086426
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# 25.159149169921875
# ...

# %%
# !python 'Wave-U-Net-Pytorch-master-fine tuning/train.py' --load_model "Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_19740" --dataset_dir 'MUSDB18_format_of_SNSD' --cuda
# Out:
# Streaming output truncated to the last 5000 lines.
#  76% 500/657 [03:47<01:12,  2.18it/s]['bass', 'drums', 'other', 'vocals']
#  76% 501/657 [03:47<01:11,  2.19it/s]['bass', 'drums', 'other', 'vocals']
#  76% 502/657 [03:48<01:10,  2.19it/s]['bass', 'drums', 'other', 'vocals']
#  77% 503/657 [03:48<01:09,  2.21it/s]['bass', 'drums', 'other', 'vocals']
#  77% 504/657 [03:48<01:09,  2.21it/s]['bass', 'drums', 'other', 'vocals']
#  77% 505/657 [03:49<01:08,  2.21it/s]['bass', 'drums', 'other', 'vocals']
#  77% 506/657 [03:49<01:07,  2.22it/s]['bass', 'drums', 'other', 'vocals']
#  77% 507/657 [03:50<01:07,  2.23it/s]['bass', 'drums', 'other', 'vocals']
#  77% 508/657 [03:50<01:06,  2.24it/s]['bass', 'drums', 'other', 'vocals']
#  77% 509/657 [03:51<01:06,  2.24it/s]['bass', 'drums', 'other', 'vocals']
#  78% 510/657 [03:51<01:05,  2.25it/s]['bass', 'drums', 'other', 'vocals']
#  78% 511/657 [03:52<01:05,  2.24it/s]['bass', 'drums', 'other', 'vocals']
# ...

# %%
# !python "Wave-U-Net-Pytorch-master-fine tuning/predict.py" --load_model "Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_7896" --input "/content/drive/MyDrive/DL Project - yaniv/audio examples/noisy speech 3 train_down - moshe/noisy7_SNRdb_20.0_clnsp7.wav" --cuda
# Out:
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# Loading model from checkpoint Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_7896
# Step 7896
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples

# %%
# !python "Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py" --load_model "Wave-U-Net-Pytorch-master-fine tuning/checkpoints/checkpoint_7896" --folder "/content/drive/MyDrive/DL Project - yaniv/MUSDB18_format_of_SNSD/test" --cuda
# Out:
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# 25.347049236297607
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# 26.623787879943848
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# 24.914638996124268
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# 23.700034618377686
# ...

# %%
# !python "Wave-U-Net-Pytorch-master-fine tuning/predict.py" --load_model "checkpoints/waveunet/model" --input "/content/drive/MyDrive/DL Project - yaniv/audio examples/noisy speech 3 waveunet_original - moshe/noisy7_SNRdb_20.0_clnsp7.wav" --cuda
# Out:
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# Loading model from checkpoint checkpoints/waveunet/model
# Step 132065
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples
# WARNING: Cropping 295893 samples

# %%
# !python "Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py" --load_model "checkpoints/waveunet/model" --folder "/content/drive/MyDrive/DL Project - yaniv/MUSDB18_format_of_SNSD/test" --cuda
# Out:
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# WARNING: Cropping 982657 samples
# 21.631784439086914
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# WARNING: Cropping 971698 samples
# 22.486801147460938
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# WARNING: Cropping 1038295 samples
# 20.74652671813965
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# WARNING: Cropping 1012162 samples
# 20.401387214660645
# ...

# %%
dbs =[0,5,10,15,20]
db=0
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test0dB'
print(f'-----------------END DB={db}----------------')
db+=5
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test5dB'
print(f'-----------------END DB={db}----------------')
db+=5
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test10dB'
print(f'-----------------END DB={db}----------------')
db+=5
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test15dB'
print(f'-----------------END DB={db}----------------')
db+=5
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test20dB'
print(f'-----------------END DB={db}----------------')

# %%
db=0
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --input '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test0dB/audio_1/mixture.wav'
print(f'-----------------END DB={db}----------------')
db+=5
db=0
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --input '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test5dB/audio_1/mixture.wav'
print(f'-----------------END DB={db}----------------')
db+=5
db=0
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --input '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test10dB/audio_1/mixture.wav'
print(f'-----------------END DB={db}----------------')
db+=5
db=0
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --input '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test15dB/audio_1/mixture.wav'
print(f'-----------------END DB={db}----------------')
db+=5
db=0
print(f'-----------------START DB={db}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --input '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_evaluation/test20dB/audio_1/mixture.wav'
print(f'-----------------END DB={db}----------------')
db+=5
# Out:
# -----------------START DB=0----------------
# Using valid convolutions with 97961 inputs and 88409 outputs
# Loading model from checkpoint /content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model
# Step 20398
# WARNING: Cropping 980690 samples
# WARNING: Cropping 980690 samples
# WARNING: Cropping 980690 samples
# WARNING: Cropping 980690 samples
# -----------------END DB=0----------------
# -----------------START DB=0----------------
# Using valid convolutions with 97961 inputs and 88409 outputs
# Loading model from checkpoint /content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model
# Step 20398
# WARNING: Cropping 980690 samples
# WARNING: Cropping 980690 samples
# WARNING: Cropping 980690 samples
# WARNING: Cropping 980690 samples
# -----------------END DB=0----------------
# -----------------START DB=0----------------
# ...

# %%
dbs =['babble','airport_announce','munch','neighor speaking','typing']
i=0
print(f'-----------------START TYPE={dbs[i]}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_noises_evaluation/babble_dataset' --cuda
print(f'-----------------END TYPE={dbs[i]}----------------')
i+=1
print(f'-----------------START TYPE={dbs[i]}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_noises_evaluation/airportannouncements_dataset' --cuda
print(f'-----------------END TYPE={dbs[i]}----------------')
i+=1
print(f'-----------------START TYPE={dbs[i]}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_noises_evaluation/munching_dataset' --cuda
print(f'-----------------END TYPE={dbs[i]}----------------')
i+=1
print(f'-----------------START TYPE={dbs[i]}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_noises_evaluation/neighborspeaking_dataset' --cuda
print(f'-----------------END TYPE={dbs[i]}----------------')
i+=1
print(f'-----------------START TYPE={dbs[i]}----------------')
# !python '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/predict_speech.py' --load_model '/content/drive/MyDrive/DL Project - yaniv/Wave-U-Net-Pytorch-master-fine tuning/checkpoints/all_params_model' --folder '/content/drive/MyDrive/DL Project - yaniv/MUSDB_format_noises_evaluation/typing_dataset' --cuda
print(f'-----------------END TYPE={dbs[i]}----------------')
# Out:
# -----------------START DB=babble----------------
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 789048 samples
# WARNING: Cropping 789048 samples
# WARNING: Cropping 789048 samples
# WARNING: Cropping 789048 samples
# 24.130229949951172
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1064428 samples
# WARNING: Cropping 1064428 samples
# WARNING: Cropping 1064428 samples
# WARNING: Cropping 1064428 samples
# 24.509458541870117
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 1046220 samples
# WARNING: Cropping 1046220 samples
# WARNING: Cropping 1046220 samples
# WARNING: Cropping 1046220 samples
# 25.93668222427368
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# WARNING: Cropping 786800 samples
# WARNING: Cropping 786800 samples
# WARNING: Cropping 786800 samples
# ...
